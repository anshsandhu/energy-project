# %%
import pandas as pd

# %%
df = pd.read_csv("df_albany.csv")

# %%
def wind_turbine_AWT26(x):
        # Importing the libraries
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    from sklearn.linear_model import LinearRegression
    
    # Considering the increase in wind speed with height
    # Shear ratio has been assumed
    height_of_turbine = 46 
    alpha = 0.14
    height_of_reading = 1 # in meters
    x_hub = x * ( height_of_turbine/height_of_reading)**alpha

    # Importing the dataset
    dataset = pd.read_csv('finished/Book1.csv')
    X = dataset.iloc[:, 0].values.reshape(-1,1)
    y = dataset.iloc[:, 1].values


    # Training the Polynomial Regression model on the whole dataset
    from sklearn.preprocessing import PolynomialFeatures
    poly_reg = PolynomialFeatures(degree = 10)
    X_poly = poly_reg.fit_transform(X)
    lin_reg_2 = LinearRegression()
    lin_reg_2.fit(X_poly, y)


    # Predicting a new result with Polynomial Regression
    if x<=20.5:
        y = lin_reg_2.predict(poly_reg.fit_transform([[x_hub]]))
        y = float(y)
    
    else:
        y = lin_reg_2.predict(poly_reg.fit_transform([[20.5]]))
        y = float(y)
        
    return(y)

# %%
def wind_turbine_AWP200(x):
        # Importing the libraries
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    from sklearn.linear_model import LinearRegression
    
    # Considering the increase in wind speed with height
    # Shear ratio has been assumed
    height_of_turbine = 30 
    alpha = 0.14
    height_of_reading = 1 # in meters
    x_hub = x * ( height_of_turbine/height_of_reading)**alpha

    # Importing the dataset
    dataset = pd.read_csv('finished/Book1.csv')
    X = dataset.iloc[:, 0].values.reshape(-1,1)
    y = dataset.iloc[:, 2].values


    # Training the Polynomial Regression model on the whole dataset
    from sklearn.preprocessing import PolynomialFeatures
    poly_reg = PolynomialFeatures(degree = 10)
    X_poly = poly_reg.fit_transform(X)
    lin_reg_2 = LinearRegression()
    lin_reg_2.fit(X_poly, y)


    # Predicting a new result with Polynomial Regression
    if x<=20.5:
        y = lin_reg_2.predict(poly_reg.fit_transform([[x_hub]]))
        y = float(y)
    
    else:
        y = lin_reg_2.predict(poly_reg.fit_transform([[20.5]]))
        y = float(y)
    return(y)

# %%
def wind_turbine_D2CF200(x):
        # Importing the libraries
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    from sklearn.linear_model import LinearRegression
    
    # Considering the increase in wind speed with height
    # Shear ratio has been assumed
    height_of_turbine = 40.3 
    alpha = 0.14
    height_of_reading = 1 # in meters
    x_hub = x * ( height_of_turbine/height_of_reading)**alpha

    # Importing the dataset
    dataset = pd.read_csv('finished/Book1.csv')
    X = dataset.iloc[:, 0].values.reshape(-1,1)
    y = dataset.iloc[:, 3].values


    # Training the Polynomial Regression model on the whole dataset
    from sklearn.preprocessing import PolynomialFeatures
    poly_reg = PolynomialFeatures(degree = 10)
    X_poly = poly_reg.fit_transform(X)
    lin_reg_2 = LinearRegression()
    lin_reg_2.fit(X_poly, y)


    # Predicting a new result with Polynomial Regression
    if x<=20.5:
        y = lin_reg_2.predict(poly_reg.fit_transform([[x_hub]]))
        y = float(y)
    
    else:
        y = lin_reg_2.predict(poly_reg.fit_transform([[20.5]]))
        y = float(y)
        
    return(y)

# %%
def wind_turbine_ANBONUS150(x):
        # Importing the libraries
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    from sklearn.linear_model import LinearRegression
    
    # Considering the increase in wind speed with height
    # Shear ratio has been assumed
    height_of_turbine = 35 
    alpha = 0.14
    height_of_reading = 1 # in meters
    x_hub = x * ( height_of_turbine/height_of_reading)**alpha

    # Importing the dataset
    dataset = pd.read_csv('finished/Book1.csv')
    X = dataset.iloc[:, 0].values.reshape(-1,1)
    y = dataset.iloc[:, 4].values


    # Training the Polynomial Regression model on the whole dataset
    from sklearn.preprocessing import PolynomialFeatures
    poly_reg = PolynomialFeatures(degree = 10)
    X_poly = poly_reg.fit_transform(X)
    lin_reg_2 = LinearRegression()
    lin_reg_2.fit(X_poly, y)


    # Predicting a new result with Polynomial Regression
    if x<=20.5:
        y = lin_reg_2.predict(poly_reg.fit_transform([[x_hub]]))
        y = float(y)
    
    else:
        y = lin_reg_2.predict(poly_reg.fit_transform([[20.5]]))
        y = float(y)
        
    return(y)

# %%
def wind_turbine_ARIA20(x):
        # Importing the libraries
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    from sklearn.linear_model import LinearRegression
    
    # Considering the increase in wind speed with height
    # Shear ratio has been assumed
    height_of_turbine = 20 
    alpha = 0.14
    height_of_reading = 1 # in meters
    x_hub = x * ( height_of_turbine/height_of_reading)**alpha

    # Importing the dataset
    dataset = pd.read_csv('finished/Book1.csv')
    X = dataset.iloc[:, 0].values.reshape(-1,1)
    y = dataset.iloc[:, 5].values


    # Training the Polynomial Regression model on the whole dataset
    from sklearn.preprocessing import PolynomialFeatures
    poly_reg = PolynomialFeatures(degree = 10)
    X_poly = poly_reg.fit_transform(X)
    lin_reg_2 = LinearRegression()
    lin_reg_2.fit(X_poly, y)


    # Predicting a new result with Polynomial Regression
    if x<=20.5:
        y = lin_reg_2.predict(poly_reg.fit_transform([[x_hub]]))
        y = float(y)
    
    else:
        y = lin_reg_2.predict(poly_reg.fit_transform([[20.5]]))
        y = float(y)
        
    return(y)

# %%
def wind_turbine_WWD(x):
        # Importing the libraries
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    from sklearn.linear_model import LinearRegression
    
    
    # Considering the increase in wind speed with height
    # Shear ratio has been assumed
    height_of_turbine = 60 
    alpha = 0.14
    height_of_reading = 1 # in meters
    x_hub = x * ( height_of_turbine/height_of_reading)**alpha
    
    

    # Importing the dataset
    dataset = pd.read_csv('finished/Book1.csv')
    X = dataset.iloc[:, 0].values.reshape(-1,1)
    y = dataset.iloc[:, 6].values


    # Training the Polynomial Regression model on the whole dataset
    from sklearn.preprocessing import PolynomialFeatures
    poly_reg = PolynomialFeatures(degree = 10)
    X_poly = poly_reg.fit_transform(X)
    lin_reg_2 = LinearRegression()
    lin_reg_2.fit(X_poly, y)


    # Predicting a new result with Polynomial Regression
    if x<=20.5:
        y = lin_reg_2.predict(poly_reg.fit_transform([[x_hub]]))
        y = float(y)
    
    else:
        y = lin_reg_2.predict(poly_reg.fit_transform([[20.5]]))
        y = float(y)
        
    return(y)

# %%
df
# Out:
#       Unnamed: 0                                 name  time  month  day  \
# 0          26277  ALBANY INTERNATIONAL AIRPORT, NY US     1      1    1
# 1          26278  ALBANY INTERNATIONAL AIRPORT, NY US     2      1    1
# 2          26279  ALBANY INTERNATIONAL AIRPORT, NY US     3      1    1
# 3          26280  ALBANY INTERNATIONAL AIRPORT, NY US     4      1    1
# 4          26281  ALBANY INTERNATIONAL AIRPORT, NY US     5      1    1
# ...          ...                                  ...   ...    ...  ...
# 8754       35031  ALBANY INTERNATIONAL AIRPORT, NY US    19     12   31
# 8755       35032  ALBANY INTERNATIONAL AIRPORT, NY US    20     12   31
# 8756       35033  ALBANY INTERNATIONAL AIRPORT, NY US    21     12   31
# 8757       35034  ALBANY INTERNATIONAL AIRPORT, NY US    22     12   31
# 8758       35035  ALBANY INTERNATIONAL AIRPORT, NY US    23     12   31
#
#       hourly_temperature  hourly_wind_speed
# 0                   -4.1                3.6
# 1                   -4.2                3.6
# 2                   -4.4                3.5
# 3                   -4.5                3.6
# 4                   -4.7                3.6
# ...                  ...                ...
# 8754                -2.6                3.9
# 8755                -2.8                3.9
# 8756                -3.1                3.8
# 8757                -3.3                3.8
# 8758                -3.6                3.7
#
# [8759 rows x 7 columns]

# %%
df['AWT26_Power'] = df['hourly_wind_speed'].apply(wind_turbine_AWT26)
df['AWP_200_Power'] = df['hourly_wind_speed'].apply(wind_turbine_AWP200)
df['D2CF_200_Power'] = df['hourly_wind_speed'].apply(wind_turbine_D2CF200)
df['AN_Bonus_150/30_Power'] = df['hourly_wind_speed'].apply(wind_turbine_ANBONUS150)
df['Aria_20_Power'] = df['hourly_wind_speed'].apply(wind_turbine_ARIA20)
df['WWD-1_D64_Power'] = df['hourly_wind_speed'].apply(wind_turbine_WWD)

# %%
df
# Out:
#       Unnamed: 0                                 name  time  month  day  \
# 0          26277  ALBANY INTERNATIONAL AIRPORT, NY US     1      1    1
# 1          26278  ALBANY INTERNATIONAL AIRPORT, NY US     2      1    1
# 2          26279  ALBANY INTERNATIONAL AIRPORT, NY US     3      1    1
# 3          26280  ALBANY INTERNATIONAL AIRPORT, NY US     4      1    1
# 4          26281  ALBANY INTERNATIONAL AIRPORT, NY US     5      1    1
# ...          ...                                  ...   ...    ...  ...
# 8754       35031  ALBANY INTERNATIONAL AIRPORT, NY US    19     12   31
# 8755       35032  ALBANY INTERNATIONAL AIRPORT, NY US    20     12   31
# 8756       35033  ALBANY INTERNATIONAL AIRPORT, NY US    21     12   31
# 8757       35034  ALBANY INTERNATIONAL AIRPORT, NY US    22     12   31
# 8758       35035  ALBANY INTERNATIONAL AIRPORT, NY US    23     12   31
#
#       hourly_temperature  hourly_wind_speed  AWT26 Power  AWP 200 Power  \
# 0                   -4.1                3.6    22.503703      23.181080
# 1                   -4.2                3.6    22.503703      23.181080
# 2                   -4.4                3.5    19.239583      19.879067
# 3                   -4.5                3.6    22.503703      23.181080
# 4                   -4.7                3.6    22.503703      23.181080
# ...                  ...                ...          ...            ...
# 8754                -2.6                3.9    33.648570      33.607124
# 8755                -2.8                3.9    33.648570      33.607124
# 8756                -3.1                3.8    29.708200      30.069277
# 8757                -3.3                3.8    29.708200      30.069277
# 8758                -3.6                3.7    25.993066      26.586012
#
#       D2CF 200 Power  AN Bonus 150/30 Power  Aria 20 Power  WWD-1 D64 Power
# 0          52.775842              33.680575       6.010686       284.762185
# 1          52.775842              33.680575       6.010686       284.762185
# 2          48.847905              30.226074       5.689710       264.743208
# 3          52.775842              33.680575       6.010686       284.762185
# 4          52.775842              33.680575       6.010686       284.762185
# ...              ...                    ...            ...              ...
# 8754       64.441728              44.678486       6.987303       345.810304
# 8755       64.441728              44.678486       6.987303       345.810304
# 8756       60.537502              40.932784       6.659245       325.120255
# 8757       60.537502              40.932784       6.659245       325.120255
# 8758       56.660182              37.258288       6.333786       304.825735
#
# [8759 rows x 13 columns]
